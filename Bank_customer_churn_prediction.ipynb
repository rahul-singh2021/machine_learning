# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul-singh2021/machine_learning/blob/main/Bank_customer_churn_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("/content/Bank Customer Churn Prediction (1).csv")

# %%
df.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %%
df.shape
# Out:
# (10000, 12)

# %%
df.columns
# Out:
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
#        'estimated_salary', 'churn'],
#       dtype='object')

# %%
dummies=pd.get_dummies(df.country)

# %%
merge=pd.concat([df,dummies],axis='columns')
df1=merge.drop(['country','France'],axis='columns')

# %%
df1
# Out:
#       customer_id  credit_score  gender  age  tenure    balance  \
# 0        15634602           619  Female   42       2       0.00
# 1        15647311           608  Female   41       1   83807.86
# 2        15619304           502  Female   42       8  159660.80
# 3        15701354           699  Female   39       1       0.00
# 4        15737888           850  Female   43       2  125510.82
# ...           ...           ...     ...  ...     ...        ...
# 9995     15606229           771    Male   39       5       0.00
# 9996     15569892           516    Male   35      10   57369.61
# 9997     15584532           709  Female   36       7       0.00
# 9998     15682355           772    Male   42       3   75075.31
# 9999     15628319           792  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn  \
# 0                   1            1              1         101348.88      1
# ...

# %%
df.isnull().sum()
# Out:
# customer_id         0
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %%
df1['gender'][df1['gender']=='Female']= 0
df1['gender'][df1['gender']=='Male']= 1
# Out:
# <ipython-input-28-04d53a477dae>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['gender'][df1['gender']=='Female']= 0
# <ipython-input-28-04d53a477dae>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['gender'][df1['gender']=='Male']= 1

# %%
df1
# Out:
#       customer_id  credit_score gender  age  tenure    balance  \
# 0        15634602           619      0   42       2       0.00
# 1        15647311           608      0   41       1   83807.86
# 2        15619304           502      0   42       8  159660.80
# 3        15701354           699      0   39       1       0.00
# 4        15737888           850      0   43       2  125510.82
# ...           ...           ...    ...  ...     ...        ...
# 9995     15606229           771      1   39       5       0.00
# 9996     15569892           516      1   35      10   57369.61
# 9997     15584532           709      0   36       7       0.00
# 9998     15682355           772      1   42       3   75075.31
# 9999     15628319           792      0   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn  \
# 0                   1            1              1         101348.88      1
# ...

# %%
x=df1.drop(['churn'],axis='columns')
y=df[['churn']]

# %%
x
# Out:
#       customer_id  credit_score gender  age  tenure    balance  \
# 0        15634602           619      0   42       2       0.00
# 1        15647311           608      0   41       1   83807.86
# 2        15619304           502      0   42       8  159660.80
# 3        15701354           699      0   39       1       0.00
# 4        15737888           850      0   43       2  125510.82
# ...           ...           ...    ...  ...     ...        ...
# 9995     15606229           771      1   39       5       0.00
# 9996     15569892           516      1   35      10   57369.61
# 9997     15584532           709      0   36       7       0.00
# 9998     15682355           772      1   42       3   75075.31
# 9999     15628319           792      0   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  Germany  \
# 0                   1            1              1         101348.88        0
# ...

# %%
y
# Out:
#       churn
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0
# ...     ...
# 9995      0
# 9996      0
# 9997      1
# 9998      1
# 9999      0
#
# [10000 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.7996

# %%
model.predict([[	15737888,	850,	0,	43,	2,	125510.82,	1,	1,	1,	79084.10,	0,	1]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])
